# %% [markdown]
# # MATPLOBLIB

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# !pip install matplotlib

# %%
years =[1950,1970,1990,2010]
pop =[2.5,3.6,5.2,6.9]
plt.plot(years,pop)
plt.show()

# %%
years =[1950,1970,1990,2010]
pop =[2.5,3.6,5.2,6.9]
plt.scatter(years,pop)
plt.xlabel("Years")
plt.ylabel("Population in CR")
plt.title("Population Increases in years")
plt.show()

# %%
values =[0,0.6,1.4,1.6,2.2,2.5,6.3,3.2,3.5,9.4,2.6,2.5,9,3.4]
plt.hist(values)
plt.show()

# %%
values =[0,0.6,1.4,1.6,2.2,2.5,6.3,3.2,3.5,9.4,2.6,2.5,9,3.4]
plt.hist(values , bins=3)
plt.show()

# %%
years = np.arange(1950,2011,10)

# %%
years
# Out:
# array([1950, 1960, 1970, 1980, 1990, 2000, 2010])

# %%
pop =[2.5,2.54,2.9,3.2,3.5,3.9,4.5]

# %%
plt.plot(years,pop,color='green')
plt.xlabel("years")
plt.ylabel("Population")
plt.title(" World Population Projection")
plt.show()

# %%
years=[1950,1960,1970,1980,1990,2000,2021,2020]
company_x =[2.5,3.5,2.8,3.1,4.0,2.9,4.5,4.8]

years=[1950,1960,1970,1980,1990,2000,2021,2020]
company_y=[2.2,3.5,2.5,3.5,4.5,2.1,4.4,4.5]

plt.subplot(1, 2, 1)
plt.plot(years,company_x,color='blue' ,marker='o', ms='10', mfc= 'green', mec='black')
plt.grid(linestyle = 'dashed' , color='black')
plt.xlabel("years")
plt.ylabel("Company_x_Captial")
plt.title("Company_X_campital Over Years")

plt.subplot(1,2,2)
plt.plot(years,company_y, color='red' ,marker='D', ms='10', mfc= 'green', mec='red')
plt.grid(linestyle = 'solid' , color='black')
plt.xlabel("years")
plt.ylabel("Company_y_Captial")
plt.title("Company_Y_campital Over Years")

plt.subplots_adjust(wspace =1)
plt.suptitle("Capital Comparison of companies Over years")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       4 years=[1950,1960,1970,1980,1990,2000,2021,2020]
#       5 company_y=[2.2,3.5,2.5,3.5,4.5,2.1,4.4,4.5]
# ----> 7 plt.subplot(1, 2, 1)
#       8 plt.plot(years,company_x,color='blue' ,marker='o', ms='10', mfc= 'green', mec='black')
#       9 plt.grid(linestyle = 'dashed' , color='black')
#
# NameError: name 'plt' is not defined
