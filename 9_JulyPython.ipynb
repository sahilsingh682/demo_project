# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
height= [62,64,69,75,66,68,65,71,76,73]
weight=[120,136,148,175,137,165,154,172,200,187]

# %%
sns.scatterplot(x=height, y=weight)
plt.show()

# %%
gender=["Female","Female","Male","Male","Female","Male","Male","Male"]
sns.countplot(x=gender)
plt.show()
# Out:
# C:\Users\kanik\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %%
file_path="C:\\Users\\kanik\\Downloads\\seaborn_data.csv"
seaborn=pd.read_csv(file_path)
seaborn.head()
# Out:
#    participant_id      age how_masculine how_important
# 0               1  18 - 34      somewhat      somewhat
# 1               2  18 - 34      somewhat      somewhat
# 2               3  18 - 34          very      not very
# 3               4  18 - 34          very      not very
# 4               5  18 - 34          very      not very

# %%
sns.countplot(x="how_masculine",data=df)
plt.show()

# %%
df = pd.read_csv("student-alcohol-consumption.csv")
df.head()
# Out:
#    Unnamed: 0 school sex  age famsize Pstatus  Medu  Fedu  traveltime  \
# 0           0     GP   F   18     GT3       A     4     4           2
# 1           1     GP   F   17     GT3       T     1     1           1
# 2           2     GP   F   15     LE3       T     1     1           1
# 3           3     GP   F   15     GT3       T     4     2           1
# 4           4     GP   F   16     GT3       T     3     3           1
#
#    failures  ... goout Dalc Walc health absences  G1  G2  G3  location  \
# 0         0  ...     4    1    1      3        6   5   6   6     Urban
# 1         0  ...     3    1    1      3        4   5   5   6     Urban
# 2         3  ...     2    2    3      3       10   7   8  10     Urban
# 3         0  ...     2    1    1      5        2  15  14  15     Urban
# 4         0  ...     2    1    2      5        4   6  10  10     Urban
#
#       study_time
# 0   2 to 5 hours
# 1   2 to 5 hours
# 2   2 to 5 hours
# 3  5 to 10 hours
# 4   2 to 5 hours
#
# ...

# %%
sns.countplot(x= "study_time", data=df)
plt.show()

# %%
sns.scatterplot(x= "school" , y="absences" ,hue="location" ,data=df)
plt.show()

# %%
df['school'].unique()
# Out:
# array(['GP', 'MS'], dtype=object)

# %%
sns.countplot(x="age" ,data=df ,hue="sex")
plt.show()

# %%
sns.relplot(x ="school", y="absences" , data=df , kind="scatter", col="location")
plt.show()

# %%
sns.relplot(x ="G1", y="absences" , data=df , kind="scatter", col="location")
plt.show()

# %%
sns.relplot(x ="G1", y="absences" , data=df , kind="scatter", row="location")
plt.show()

# %%
sns.relplot(x ="G1", y="absences" , data=df , kind="scatter", row="location")
plt.show()

# %%
sns.relplot(x ="G1", y="absences" , data=df , kind="scatter", row="school")
plt.show()

# %%
sns.relplot(x ="G1", y="absences" , data=df , kind="scatter", col="school",row="sex")
plt.show()

# %%
Use relplot() to create a scatter plot with "G1" on the x-axis and G2 on the y-axis
# Out:
#   Cell In[81], line 1
#     Use relplot() to create a scatter
#         ^
# SyntaxError: invalid syntax

# %%
sns.relplot(x="G1", y="G3", kind="scatter" , data=df)
plt.show()

# %%
sns.relplot(x="G1",y="G2",data=df, kind="scatter", col="schoolsup",col_order=["yes","no"])
plt.show()

# %%
sns.relplot(x="G1",y="G2",data=df, kind="scatter", col="schoolsup",col_order=["yes","no"] ,row="famsup",row_order=["yes","no"])
plt.show()
